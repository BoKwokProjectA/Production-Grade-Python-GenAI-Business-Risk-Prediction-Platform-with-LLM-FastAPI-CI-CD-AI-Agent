# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
PROJECT_ROOT = "/content/drive/MyDrive/isic-flagship-project"
os.makedirs(PROJECT_ROOT, exist_ok=True)
os.chdir(PROJECT_ROOT)
print("Project root created at:", os.getcwd())

# Create folder structure
folders = [
    "src/api", "src/schemas", "src/services", "src/repositories",
    "src/models", "src/inference", "src/rag", "src/core", "src/utils",
    "src/db", "tests", "configs", "logs", "data", "notebooks",
    "docker", ".github/workflows"
]
for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"Created: {folder}")

# Create essential empty files
files = [
    "src/__init__.py", "src/api/__init__.py", "src/schemas/__init__.py",
    "src/services/__init__.py", "src/repositories/__init__.py",
    "src/core/__init__.py", "src/utils/__init__.py", "src/db/__init__.py",
    "requirements.txt", "README.md", ".env.example", "pyproject.toml",
    "Dockerfile", ".gitignore"
]
for f in files:
    open(f, "w").close()
    print(f"Created file: {f}")

print("Structure initialized")
# Out:
# Project root created at: /content/drive/MyDrive/isic-flagship-project
# Created: src/api
# Created: src/schemas
# Created: src/services
# Created: src/repositories
# Created: src/models
# Created: src/inference
# Created: src/rag
# Created: src/core
# Created: src/utils
# Created: src/db
# Created: tests
# Created: configs
# Created: logs
# Created: data
# Created: notebooks
# Created: docker
# Created: .github/workflows
# Created file: src/__init__.py
# Created file: src/api/__init__.py
# Created file: src/schemas/__init__.py
# Created file: src/services/__init__.py
# Created file: src/repositories/__init__.py
# Created file: src/core/__init__.py
# Created file: src/utils/__init__.py
# Created file: src/db/__init__.py
# Created file: requirements.txt
# Created file: README.md
# Created file: .env.example
# Created file: pyproject.toml
# Created file: Dockerfile
# Created file: .gitignore
# Structure initialized

# %%
# !pip install -r requirements.txt --quiet
# !pip install pyngrok --quiet
print("Dependencies installed")
# Out:
# Dependencies installed

# %%
# %%writefile requirements.txt
# fastapi==0.115.2
# uvicorn==0.32.0
# pydantic==2.9.2
# sqlalchemy==2.0.35
# alembic==1.13.2
# python-dotenv==1.0.1
# pandas==2.2.2
# numpy==1.26.4
# torch==2.3.1+cu121
# torchvision==0.18.1+cu121
# timm==1.0.11
# lightgbm==4.5.0
# catboost==1.2.7
# xgboost==2.1.1
# scikit-learn==1.5.2
# langchain==0.3.4
# langchain-community==0.3.3
# faiss-cpu==1.10.1
# sentence-transformers==3.1.1
# python-multipart==0.0.9
# httpx==0.27.2
# structlog==24.4.0
# pyngrok==7.2.0
# Out:
# Overwriting requirements.txt

# %%
# %%writefile .env.example
# from google.colab import userdata
#
# NGROK_AUTHTOKEN = userdata.get("NGROK_AUTHTOKEN")
# APP_NAME=ISIC2024-Flagship
# API_VERSION=v1
# MODEL_VERSION=2024-ensemble-v1
# DEBUG=True
# DATABASE_URL=sqlite+aiosqlite:///./isic.db
# SECRET_KEY=super-secret-key-change-in-production
# Out:
# Overwriting .env.example
